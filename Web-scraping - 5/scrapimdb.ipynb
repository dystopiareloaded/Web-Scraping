# %% [markdown]
# # Using HTML

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
with open('IMDb Top 250 Movies.html', 'r', encoding='utf-8') as f:
    html = f.read()

# %%
soup = BeautifulSoup(html,'lxml')

# %%
movies = soup.find_all('li', class_= 'ipc-metadata-list-summary-item')

# %%
ranks, movie_name, years, ratings = [] , [] , [] , []

for movie in movies:
    name = movie.find('div', class_= 'sc-2bbfc9e9-0 jUYPWY cli-children').find('a').get_text(strip=True).split(".")[1]
    rank = movie.find('div', class_= 'sc-2bbfc9e9-0 jUYPWY cli-children').find('a').get_text(strip=True).split(".")[0]
    year = movie.find('div', class_= 'sc-2bbfc9e9-6 cZkKPy cli-title-metadata').find('span').text
    #yr = movie.find('span', class_= 'sc-2bbfc9e9-7 jttFlJ cli-title-metadata-item').text
    rating = movie.find('span', class_= 'ipc-rating-star--rating').text

    ranks.append(rank)
    movie_name.append(name)
    years.append(year)
    ratings.append(rating)

# %%
# Create DataFrame
df = pd.DataFrame({
    "Rank": ranks,
    "Title": movie_name,
    "Year": years,
    "Rating": ratings
})

# %%
df
# Out:
#     Rank                                              Title  Year Rating
# 0      1                           The Shawshank Redemption  1994    9.3
# 1      2                                      The Godfather  1972    9.2
# 2      3                                    The Dark Knight  2008    9.0
# 3      4                              The Godfather Part II  1974    9.0
# 4      5                                       12 Angry Men  1957    9.0
# ..   ...                                                ...   ...    ...
# 245  246                                      Groundhog Day  1993    8.0
# 246  247                                           The Help  2011    8.1
# 247  248   Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mans...  2021    8.5
# 248  249                                      Amores Perros  2000    8.0
# 249  250                                            Rebecca  1940    8.1
#
# [250 rows x 4 columns]

# %%
df.to_csv('IMDB_Top_250_Movies.csv',index=False)
